# %% [markdown]
# # Taller 2
# ### Daniel Felipe Segura Rincon
# ### Andres Felipe Zuleta Romero
# ### Juan Andres Barrera Rodriguez

# %%
import cv2
from PIL import Image
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
biciclera = cv2.imread('Imagenes/Bicicleta.jpg',0)
bus = cv2.imread('Imagenes/Bus.jpg',0)
carro = cv2.imread('Imagenes/Carro.jpg',0)
pare = cv2.imread("Imagenes/Pare.jpg",0)
planta = cv2.imread('Imagenes/Planta.jpg',0)

# %%
plt.imshow(bus,cmap='Greys')

# %%
N_kernel = np.array([[-1, -1, -1],[1, -2, 1],[1, 1, 1]])

# %%
bus= cv2.filter2D(bus,'bus_filtro',-1,kernel=N_kernel)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 bus= cv2.filter2D(bus,'bus_filtro',-1,kernel=N_kernel)
#
# error: OpenCV(4.9.0) :-1: error: (-5:Bad argument) in function 'filter2D'
# > Overload resolution failed:
# >  - argument for filter2D() given by name ('kernel') and position (3)
# >  - argument for filter2D() given by name ('kernel') and position (3)
